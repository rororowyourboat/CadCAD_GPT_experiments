# %%
# %pip install -r requirements.txt
# Out:
# ...
#   Using cached radcad-0.8.4-py3-none-any.whl (23 kB)
# ...
#   Using cached plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
# ...
#   Using cached openai-0.28.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# ...
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# ...
#   Using cached pydantic-1.10.11-cp39-cp39-win_amd64.whl.metadata (150 kB)
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# ...
#   Using cached pandas-1.5.3-cp39-cp39-win_amd64.whl (10.9 MB)
# ...
#   Using cached pathos-0.2.9-py3-none-any.whl (76 kB)
# ...
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# ...
#   Using cached PyYAML-6.0.1-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached SQLAlchemy-2.0.22-cp39-cp39-win_amd64.whl.metadata (9.7 kB)
# ...
#   Using cached aiohttp-3.8.6-cp39-cp39-win_amd64.whl.metadata (7.9 kB)
# ...
#   Using cached anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# ...

# %%
# %pip install tiktoken
# %pip install faiss-cpu
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/10.8 MB 445.2 kB/s eta 0:00:25
#       --------------------------------------- 0.2/10.8 MB 2.4 MB/s eta 0:00:05
#      - -------------------------------------- 0.5/10.8 MB 4.4 MB/s eta 0:00:03
#      --- ------------------------------------ 0.9/10.8 MB 6.0 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.3/10.8 MB 6.4 MB/s eta 0:00:02
#      ------ --------------------------------- 1.7/10.8 MB 7.3 MB/s eta 0:00:02
#      ------- -------------------------------- 2.0/10.8 MB 7.0 MB/s eta 0:00:02
#      -------- ------------------------------- 2.2/10.8 MB 7.0 MB/s eta 0:00:02
#      -------- ------------------------------- 2.4/10.8 MB 6.7 MB/s eta 0:00:02
#      --------- ------------------------------ 2.5/10.8 MB 6.4 MB/s eta 0:00:02
# ...

# %%
# %pip install nbformat
# Out:
# ...
#    ---------------------------------------- 0.0/77.6 kB ? eta -:--:--
#    ---------------------------------------- 77.6/77.6 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/83.3 kB ? eta -:--:--
#    ---------------------------------------- 83.3/83.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/186.2 kB ? eta -:--:--
#    --------------------------------------- 186.2/186.2 kB 11.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
